# %% [markdown]
# # 002 – Jetson Nano Terminal Basics and GPU Check
#
# In this notebook, you will **learn the basic terminal commands on Jetson Nano**, update the system, and **verify that the GPU and CUDA are working correctly**.
#
# > This file is for explanation only. Participants should *type these commands in the Jetson Nano terminal*.

# %% [markdown]
# ## 1. Open the terminal on Jetson Nano
#
# On the Jetson Nano Ubuntu desktop:
#
# - Click the **terminal icon** in the top bar / side bar, or
# - Press **Ctrl + Alt + T** on the keyboard.
#
# You should see a black window with a prompt similar to:
#
# ``````

# %% [markdown]
# ## 2. Basic navigation commands
#
# These commands help you move around the file system and inspect files.
#
# ### 2.1 Show current directory
#
# ``````
#
# ### 2.2 List files and folders
#
# ``````
#
# ### 2.3 Change directory
#
# ``````
#
# ### 2.4 Create and remove folders
#
# ``````

# %% [markdown]
# ## 3. Check system resources
#
# These commands show CPU, RAM, and disk usage.
#
# ### 3.1 Disk usage
#
# ``````
#
# ### 3.2 Memory usage
#
# ``````
#
# ### 3.3 Processes (optional)
#
# ``````
#
# Press `q` to quit **top**.

# %% [markdown]
# ## 4. Update and upgrade the system
#
# Make sure the Jetson Nano has an internet connection (Ethernet or Wi‑Fi) before running these commands.
#
# ``````
#
# - `sudo apt update` refreshes the package list.
# - `sudo apt upgrade` installs the latest versions of installed packages.
#
# You may be asked for your password. Type it and press **Enter**.

# %% [markdown]
# ## 5. Install basic developer tools
#
# Install some common tools that will be useful throughout the workshop.
#
# ``````
#
# Optionally, you can also install a terminal editor such as **nano** or **vim**:
#
# ``````

# %% [markdown]
# ## 6. Check CUDA and GPU status
#
# Jetson Nano comes with NVIDIA JetPack, which includes CUDA and other GPU tools.
#
# ### 6.1 Check CUDA version (if `nvcc` is available)
#
# ``````
#
# If this prints a version, CUDA is installed and accessible.
#
# ### 6.2 Check GPU utilization with `tegrastats`
#
# ``````
#
# You will see a continuous stream of system statistics, including GPU usage. Press `Ctrl + C` to stop.

# %% [markdown]
# ## 7. Simple Python GPU check (PyTorch example)
#
# > This section assumes that PyTorch is already installed on the Jetson Nano. If not, the command will fail and you can install it later in another session.
#
# Open Python from the terminal:
#
# ``````
#
# Then, inside the Python prompt, type:
#
# ``````
#
# If `torch.cuda.is_available()` prints `True`, your GPU is ready for deep learning workloads.
#
# Exit Python:
#
# ``````

# %% [markdown]
# ## 8. Summary and next steps
#
# By now, participants should be able to:
#
# - Open and use the terminal on Jetson Nano.
# - Navigate the file system and check system resources.
# - Update the system and install basic tools.
# - Verify that CUDA and the GPU are recognized.
#
# In the **next file**, you can introduce a simple **AI demo on the Jetson Nano** (for example, running a pre‑trained image classification or object detection script using the GPU).
